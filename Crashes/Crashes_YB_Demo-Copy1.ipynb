# %%
import pandas as pd
import numpy as np
import yellowbrick
import matplotlib as plt
import seaborn
import bokeh
import io

# %%
df = pd.read_csv('../../downloads/crashes/data/Crash_Details_Table.csv', header = 0, names=['OBJECTID','CRIMEID','CCN','PERSONID','PERSONTYPE','AGE','MAJORINJURY','MINORINJURY','VEHICLEID','INVEHICLETYPE','TICKETISSUED','LICENSEPLATESTATE','IMPAIRED','SPEEDING'])
print(df)
# Out:
#           OBJECTID   CRIMEID       CCN PERSONID  PERSONTYPE AGE MAJORINJURY  \
# 61035005  24674744  13101652  84867289   Driver        34.0   N           N
# 61035006  24668659  13099590  84894742   Driver        45.0   N           N
# 61035007  24674040  13102542  84701349   Driver        64.0   N           N
# 61035008  24678138  13104277  84976435   Driver         NaN   N           N
# 61986561  24678354  13103641  84750291   Driver         NaN   N           N
# 61986562  24680644  13104743  85007528   Driver        36.0   N           N
# 61986563  24682398  13106280  84638041   Driver         NaN   N           N
# 61986564  24682398  13106280  84597562   Driver        51.0   N           N
# 61986565  24678704  13103616  84872340   Driver         NaN   N           N
# 61986566  24670484  13100066  84575668   Driver        59.0   N           N
# 61986567  24674694  13102045  84978154   Driver        34.0   N           N
# ...

# %%
df1 = df[['PERSONID', 'PERSONTYPE', 'AGE','INVEHICLETYPE', 'TICKETISSUED', 'LICENSEPLATESTATE', 'IMPAIRED', 'SPEEDING']]

# %%
df1.head()
# Out:
#          PERSONID  PERSONTYPE AGE                INVEHICLETYPE TICKETISSUED  \
# 61035005   Driver        34.0   N                Other Vehicle            N
# 61035006   Driver        45.0   N     Passenger Car/automobile            N
# 61035007   Driver        64.0   N  Suv (sport Utility Vehicle)            N
# 61035008   Driver         NaN   N     Passenger Car/automobile            N
# 61986561   Driver         NaN   N     Passenger Car/automobile            N
#
#          LICENSEPLATESTATE IMPAIRED SPEEDING
# 61035005               NaN        N        N
# 61035006                MD        N        N
# 61035007                MD        N        N
# 61035008                DC        N        N
# 61986561                MD        N        N

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316886 entries, 0 to 316885
# Data columns (total 9 columns):
# PERSONID             316886 non-null int64
# PERSONTYPE           316886 non-null object
# AGE                  202227 non-null float64
# FATAL                316886 non-null object
# INVEHICLETYPE        316801 non-null object
# TICKETISSUED         316886 non-null object
# LICENSEPLATESTATE    289914 non-null object
# IMPAIRED             316886 non-null object
# SPEEDING             316886 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 21.8+ MB

# %%
[df1['FATAL']=='Y']
# Out:
# [0         False
#  1         False
#  2         False
#  3         False
#  4         False
#  5         False
#  6         False
#  7         False
#  8         False
#  9         False
#  10        False
#  11        False
#  12        False
#  13        False
#  14        False
#  15        False
#  16        False
#  17        False
#  18        False
#  19        False
#  20        False
#  21        False
#  22        False
#  23        False
#  24        False
#  25        False
#  26        False
#  27        False
#  28        False
#  29        False
#            ...
#  316856    False
#  316857    False
#  316858    False
#  316859    False
#  316860    False
#  316861    False
#  316862    False
#  316863    False
#  316864    False
#  316865    False
#  316866    False
#  316867    False
#  316868    False
#  316869    False
#  316870    False
#  316871    False
#  316872    False
#  316873    False
#  316874    False
#  316875    False
#  316876    False
# ...
