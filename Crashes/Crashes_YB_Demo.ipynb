# %%
import pandas as pd
import numpy as np
import yellowbrick
import matplotlib as plt
import seaborn
import bokeh
import io

# %%
df = pd.read_csv('../../downloads/crashes/data/Crash_Details_Table.csv', header = 0, names=['OBJECTID','CRIMEID','CCN','PERSONID','PERSONTYPE','AGE','FATAL','MAJORINJURY','MINORINJURY','VEHICLEID','INVEHICLETYPE','TICKETISSUED','LICENSEPLATESTATE','IMPAIRED','SPEEDING'])
df
# Out:
# /Users/adammorris/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         OBJECTID   CRIMEID       CCN  PERSONID PERSONTYPE   AGE FATAL  \
# 0       61035005  24674744  13101652  84867289     Driver  34.0     N
# 1       61035006  24668659  13099590  84894742     Driver  45.0     N
# 2       61035007  24674040  13102542  84701349     Driver  64.0     N
# 3       61035008  24678138  13104277  84976435     Driver   NaN     N
# 4       61986561  24678354  13103641  84750291     Driver   NaN     N
# 5       61986562  24680644  13104743  85007528     Driver  36.0     N
# 6       61986563  24682398  13106280  84638041     Driver   NaN     N
# 7       61986564  24682398  13106280  84597562     Driver  51.0     N
# 8       61986565  24678704  13103616  84872340     Driver   NaN     N
# ...

# %%
df1 = df[['PERSONID', 'PERSONTYPE', 'AGE', 'FATAL','INVEHICLETYPE', 'TICKETISSUED', 'LICENSEPLATESTATE', 'IMPAIRED', 'SPEEDING', 'IMPAIRED', 'SPEEDING']]

# %%
df1.head()
# Out:
#    PERSONID PERSONTYPE   AGE FATAL                INVEHICLETYPE TICKETISSUED  \
# 0  84867289     Driver  34.0     N                Other Vehicle            N
# 1  84894742     Driver  45.0     N     Passenger Car/automobile            N
# 2  84701349     Driver  64.0     N  Suv (sport Utility Vehicle)            N
# 3  84976435     Driver   NaN     N     Passenger Car/automobile            N
# 4  84750291     Driver   NaN     N     Passenger Car/automobile            N
#
#   LICENSEPLATESTATE IMPAIRED SPEEDING IMPAIRED SPEEDING
# 0               NaN        N        N        N        N
# 1                MD        N        N        N        N
# 2                MD        N        N        N        N
# 3                DC        N        N        N        N
# 4                MD        N        N        N        N

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316886 entries, 0 to 316885
# Data columns (total 11 columns):
# PERSONID             316886 non-null int64
# PERSONTYPE           316886 non-null object
# AGE                  202227 non-null float64
# FATAL                316886 non-null object
# INVEHICLETYPE        316801 non-null object
# TICKETISSUED         316886 non-null object
# LICENSEPLATESTATE    289914 non-null object
# IMPAIRED             316886 non-null object
# SPEEDING             316886 non-null object
# IMPAIRED             316886 non-null object
# SPEEDING             316886 non-null object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 26.6+ MB

# %%
df1('AGE').head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-09868c6820f2> in <module>()
# ----> 1 df1('AGE').head()
#
# TypeError: 'DataFrame' object is not callable
