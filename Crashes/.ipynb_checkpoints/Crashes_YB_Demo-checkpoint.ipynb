# %%
import pandas as pd
import numpy as np
import yellowbrick
import matplotlib as plt
import seaborn
import bokeh
import io

# %%
df = pd.read_csv('../../downloads/crashes/data/Crash_Details_Table.csv', names=['OBJECTID','CRIMEID','CCN','PERSONID','PERSONTYPE','AGE','FATAL','MAJORINJURY','MINORINJURY','VEHICLEID','INVEHICLETYPE','TICKETISSUED','LICENSEPLATESTATE','IMPAIRED','SPEEDING'])
df
# Out:
# /Users/adammorris/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,1,2,3,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         OBJECTID   CRIMEID       CCN  PERSONID  PERSONTYPE  AGE  FATAL  \
# 0       OBJECTID   CRIMEID       CCN  PERSONID  PERSONTYPE  AGE  FATAL
# 1       61035005  24674744  13101652  84867289      Driver   34      N
# 2       61035006  24668659  13099590  84894742      Driver   45      N
# 3       61035007  24674040  13102542  84701349      Driver   64      N
# 4       61035008  24678138  13104277  84976435      Driver  NaN      N
# 5       61986561  24678354  13103641  84750291      Driver  NaN      N
# 6       61986562  24680644  13104743  85007528      Driver   36      N
# 7       61986563  24682398  13106280  84638041      Driver  NaN      N
# ...

# %%
df1 = df[['PERSONID', 'PERSONTYPE', 'AGE', 'INVEHICLETYPE', 'TICKETISSUED', 'LICENSEPLATESTATE', 'IMPAIRED', 'SPEEDING', 'IMPAIRED', 'SPEEDING']]

# %%
df1.head()
# Out:
#        PERSONID  PERSONTYPE  AGE                INVEHICLETYPE  TICKETISSUED  \
# FATAL
# FATAL  PERSONID  PERSONTYPE  AGE                INVEHICLETYPE  TICKETISSUED
# N      84867289      Driver   34                Other Vehicle             N
# N      84894742      Driver   45     Passenger Car/automobile             N
# N      84701349      Driver   64  Suv (sport Utility Vehicle)             N
# N      84976435      Driver  NaN     Passenger Car/automobile             N
#
#        LICENSEPLATESTATE  IMPAIRED  SPEEDING  IMPAIRED  SPEEDING
# FATAL
# FATAL  LICENSEPLATESTATE  IMPAIRED  SPEEDING  IMPAIRED  SPEEDING
# N                    NaN         N         N         N         N
# N                     MD         N         N         N         N
# N                     MD         N         N         N         N
# N                     DC         N         N         N         N

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 316887 entries, FATAL to N
# Data columns (total 10 columns):
# PERSONID             316887 non-null object
# PERSONTYPE           316887 non-null object
# AGE                  202228 non-null object
# INVEHICLETYPE        316802 non-null object
# TICKETISSUED         316887 non-null object
# LICENSEPLATESTATE    289915 non-null object
# IMPAIRED             316887 non-null object
# SPEEDING             316887 non-null object
# IMPAIRED             316887 non-null object
# SPEEDING             316887 non-null object
# dtypes: object(10)
# memory usage: 26.6+ MB

# %%
df1==df1.query('AGE==34')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-abfe0ce9e584> in <module>()
# ----> 1 df1==df1.query('AGE==34')
#
# /Users/adammorris/anaconda/lib/python3.5/site-packages/pandas/core/ops.py in f(self, other)
#    1288     def f(self, other):
#    1289         if isinstance(other, pd.DataFrame):  # Another DataFrame
# -> 1290             return self._compare_frame(other, func, str_rep)
#    1291         elif isinstance(other, ABCSeries):
#    1292             return self._combine_series_infer(other, func)
#
# /Users/adammorris/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _compare_frame(self, other, func, str_rep)
#    3652     def _compare_frame(self, other, func, str_rep):
#    3653         if not self._indexed_same(other):
# -> 3654             raise ValueError('Can only compare identically-labeled '
# ...
